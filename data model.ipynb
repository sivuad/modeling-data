# %%
import pandas as pd
import sqlite3
import math
import datetime 
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 44em; }</style>"))
# Out:
# <style>div.output_scroll { height: 44em; }</style>

# %%
conn = sqlite3.connect('database.db')

# %%
c = conn.cursor()

# %%
df = pd.read_csv("bundesliga_top7_offensive.csv")
df
# Out:
#                    Name           Club Nationality Position  Age  Matches  \
# 0          Manuel Neuer  Bayern Munich         GER       GK   34       33
# 1         Thomas Müller  Bayern Munich         GER       MF   30       32
# 2           David Alaba  Bayern Munich         AUT    DF,MF   28       32
# 3        Jérôme Boateng  Bayern Munich         GER       DF   31       29
# 4    Robert Lewandowski  Bayern Munich         POL       FW   31       29
# ..                  ...            ...         ...      ...  ...      ...
# 172        Loris Karius   Union Berlin         GER       GK   27        4
# 173         Akaki Gogia   Union Berlin         GER       FW   28        7
# 174         Leon Dajaku   Union Berlin         GER       FW   19        2
# 175     Tim Maciejewski   Union Berlin         GER       MF   19        1
# 176         Joshua Mees   Union Berlin         GER       FW   24        1
#
#      Starts  Mins  Goals  Assists  Penalty_Goals  Penalty_Attempted    xG  \
# 0        33  2970      0        0              0                  0  0.00
# 1        31  2674     11       19              1                  1  0.24
# 2        30  2675      2        4              0                  0  0.04
# 3        29  2368      1        1              0                  0  0.01
# 4        28  2458     41        7              8                  9  1.16
# ..      ...   ...    ...      ...            ...                ...   ...
# 172       3   292      0        0              0                  0  0.00
# 173       0   140      0        1              0                  0  0.09
# 174       0    37      0        0              0                  0  0.00
# 175       0     8      0        0              0                  0  0.00
# 176       0     5      0        0              0                  0  2.02
#
#        xA  Yellow_Cards  Red_Cards
# 0    0.01             1          0
# 1    0.39             0          0
# 2    0.08             4          0
# 3    0.02             6          0
# 4    0.13             4          0
# ..    ...           ...        ...
# 172  0.00             0          0
# 173  0.28             1          0
# 174  0.00             0          0
# 175  0.00             0          0
# 176  0.00             0          0
#
# [177 rows x 16 columns]

# %%
df.columns = ['Name', 'Club', 'Position']
df.index = np.arange(1,len(df)+1)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a8aca0150bb0> in <module>
# ----> 1 df.columns = ['Name', 'Club', 'Position']
#       2 df.index = np.arange(1,len(df)+1)
#       3 df
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     224
#     225         if new_len != old_len:
# --> 226             raise ValueError(
#     227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 16 elements, new values have 3 elements
